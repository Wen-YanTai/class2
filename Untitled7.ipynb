# %%
letter='abcde,fghi,jklmno,pqrst,uvwxyz'
len(letter)
# Out:
# 30

# %%
letter.split(',')
# Out:
# ['abcde', 'fghi', 'jklmno', 'pqrst', 'uvwxyz']

# %%
type('letter')
# Out:
# str

# %%
news = '''中國時報【呂昭隆╱台北報導】
軍情局內部出版《情報典範人物》，以第一手檔案，介紹我著名007，如沈之岳計畫暗殺劉少奇，及蔣介石的「十三太保」鄭介民、戴笠的「四大金剛」陳恭澍，當年暗殺漢奸行動任務均獲證實，這是軍情局首次公開檔案，証實傳聞軍統時期的暗殺任務。
逢大雨 暗殺功敗垂成
《情報典範人物》介紹情報無名英雄中，首度證實「調查局之父」沈之岳，1963年以情報局副局長身分潛入澳門，執行指揮制裁劉少奇行動。另，沈之岳在共黨眼中，是抗大二期名為「沈輝」的畢業生；國府面前，是化名「李國棟」的情報人員，沒人知道他們是同一人。
1963年劉少奇出訪高棉，情報局下達暗殺任務；從金邊機場到皇宮，即劉少奇預訂下榻處，只有一條公路，路基很高，兩側都是民宅，情報局透過管道租一民宅，再挖地洞到公路下面，埋好炸藥，待劉少奇車隊經過引爆。
鄭介民主謀刺殺張敬堯
但一場傾盆大雨，將本就不結實的路基沖陷，挖洞埋炸藥的那段更整個下陷，計畫敗露；這起暗殺劉少奇計畫，現仍列永久機密，存放軍情局檔案中。
此外，介紹我情報史軍階最高（逝世後追贈陸軍一級上將）的鄭介民時，指出這位軍統骨幹人物，亦為蔣總統「十三太保」之一，當年主持刺殺湖南軍閥張敬堯任務。
《情報典範人物》是對我情報史料專研極深的軍情局長劉德良，任職軍情學校校長時編輯，不對外發行，僅刊200本。
陳恭澍參與200起獲推崇
軍情局特別推崇陳恭澍，這位並未寫在《情報典範人物》中的情報員，是戴笠手下「四大金剛」之一。
軍情局檔案顯示，陳恭澍1933年在鄭介民指揮下，於北京六國飯店制裁北洋皖系軍閥張敬堯；1934年11月，利用掩護身分制裁西北軍高級將領吉鴻昌；同年冬，制裁臭名昭著的倒戈將軍石友三；1935年至1938年，連續計畫制裁大漢奸殷汝耕；1938年3月制裁華北頭號大漢奸王克敏，1940年，制裁日本上海公租界警務副總監赤木親之。
根據檔案，陳恭澍一生共策畫參與200多起制裁案件，制裁日人、漢奸、敵對勢力成其「職業生涯」的主要任務。'''
len(news)
# Out:
# 839

# %%
news.split('，')
# Out:
# ['中國時報【呂昭隆╱台北報導】\n軍情局內部出版《情報典範人物》',
#  '以第一手檔案',
#  '介紹我著名007',
#  '如沈之岳計畫暗殺劉少奇',
#  '及蔣介石的「十三太保」鄭介民、戴笠的「四大金剛」陳恭澍',
#  '當年暗殺漢奸行動任務均獲證實',
#  '這是軍情局首次公開檔案',
#  '証實傳聞軍統時期的暗殺任務。\n逢大雨 暗殺功敗垂成\n《情報典範人物》介紹情報無名英雄中',
#  '首度證實「調查局之父」沈之岳',
#  '1963年以情報局副局長身分潛入澳門',
#  '執行指揮制裁劉少奇行動。另',
#  '沈之岳在共黨眼中',
#  '是抗大二期名為「沈輝」的畢業生；國府面前',
#  '是化名「李國棟」的情報人員',
#  '沒人知道他們是同一人。\n1963年劉少奇出訪高棉',
#  '情報局下達暗殺任務；從金邊機場到皇宮',
#  '即劉少奇預訂下榻處',
#  '只有一條公路',
#  '路基很高',
#  '兩側都是民宅',
#  '情報局透過管道租一民宅',
#  '再挖地洞到公路下面',
#  '埋好炸藥',
#  '德良，任職軍情學校校長時編輯，不對外發行，僅刊200本。\n陳恭澍參與200起獲推崇\n軍情局特別推崇陳恭澍，這位並未寫在《情報典範人物》中的情報員，是戴笠手下「四大金剛」之一。\n軍情局檔案顯示，陳恭澍1933年在鄭介民指揮下，於北京六國飯店制裁北洋皖系軍閥張敬堯；1934年11月，利用掩護身分制裁西北軍高級將領吉鴻昌；同年冬，制裁臭名昭著的倒戈將軍石友三；1935年至1938年，連續計畫制裁大漢奸殷汝耕；1938年3月制裁華北頭號大漢奸王克敏，1940年，制裁日本上海公租界警務副總監赤木親之。\n根據檔案，陳恭澍一生共策畫參與200多起制裁案件，制裁日人、漢奸、敵對勢力成其「職業生涯」的主要任務。']

# %%
news_string = ','.join(news)
print('found:',news_string)
# Out:
# found: 中,國,時,報,【,呂,昭,隆,╱,台,北,報,導,】,
# ,軍,情,局,內,部,出,版,《,情,報,典,範,人,物,》,，,以,第,一,手,檔,案,，,介,紹,我,著,名,0,0,7,，,如,沈,之,岳,計,畫,暗,殺,劉,少,奇,，,及,蔣,介,石,的,「,十,三,太,保,」,鄭,介,民,、,戴,笠,的,「,四,大,金,剛,」,陳,恭,澍,，,當,年,暗,殺,漢,奸,行,動,任,務,均,獲,證,實,，,這,是,軍,情,局,首,次,公,開,檔,案,，,証,實,傳,聞,軍,統,時,期,的,暗,殺,任,務,。,
# ,逢,大,雨, ,暗,殺,功,敗,垂,成,
# ,《,情,報,典,範,人,物,》,介,紹,情,報,無,名,英,雄,中,，,首,度,證,實,「,調,查,局,之,父,」,沈,之,岳,，,1,9,6,3,年,以,情,報,局,副,局,長,身,分,潛,入,澳,門,，,執,行,指,揮,制,裁,劉,少,奇,行,動,。,另,，,沈,之,岳,在,共,黨,眼,中,，,是,抗,大,二,期,名,為,「,沈,輝,」,的,畢,業,生,；,國,府,面,前,，,是,化,名,「,李,國,棟,」,的,情,報,人,員,，,沒,人,知,道,他,們,是,同,一,人,。,
# ,1,9,6,3,年,劉,少,奇,出,訪,高,棉,，,情,報,局,下,達,暗,殺,任,務,；,從,金,邊,機,場,到,皇,宮,，,即,劉,少,奇,預,訂,下,榻,處,，,只,有,一,條,公,路,，,路,基,很,高,，,兩,側,都,是,民,宅,，,情,報,局,透,過,管,道,租,一,民,宅,，,再,挖,地,洞,到,公,路,下,面,，,埋,好,炸,藥,，,待,劉,少,奇,車,隊,經,過,引,爆,。,
# ,鄭,介,民,主,謀,刺,殺,張,敬,堯,
# ,但,一,場,傾,盆,大,雨,，,將,本,就,不,結,實,的,路,基,沖,陷,，,挖,洞,埋,炸,藥,的,那,段,更,整,個,下,陷,，,計,畫,敗,露,；,這,起,暗,殺,劉,少,奇,計,畫,，,現,仍,列,永,久,機,密,，,存,放,軍,情,局,檔,案,中,。,
# ...

# %%
import requests
response = requests.get("http://www.novelscape.net/wxxs/j/jingyong/sdxl/001.htm")
response.encoding = "big5"
book1= response.text

# %%
word = "怪客"
book1.count(word)
# Out:
# 46

# %%
book1.startswith('幹')
# Out:
# False

# %%
book1.find(word)
# Out:
# 2386

# %%
book1.rfind(word)
# Out:
# 12912

# %%
book1.isalnum()
# Out:
# False

# %%
A = 'fuck your mother'
A.capitalize()
# Out:
# 'Fuck your mother'

# %%
A.title()
# Out:
# 'Fuck Your Mother'

# %%
A.upper()
# Out:
# 'FUCK YOUR MOTHER'

# %%
A.replace('fuck','ask')
# Out:
# 'ask your mother'
